# %%
import matplotlib.pyplot as plt

# %%
data = [1, 2, 3, 4]

# %%
plt.plot( data )
plt.show()

# %%
x = [1, 2, 3, 4]
y = [i**2 for i in x ]

# %%
x
# Out:
# [1, 2, 3, 4]

# %%
y
# Out:
# [1, 4, 9, 16]

# %%
# %matplotlib inline
plt.plot(x,y)

# %%
# %matplotlib qt
plt.plot(x,y)
